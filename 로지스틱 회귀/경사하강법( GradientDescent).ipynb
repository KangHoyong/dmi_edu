# %%
import numpy as np 
import matplotlib.pyplot as plt
import torch

torch.manual_seed(1)

x = 2*np.random.rand(100, 1)
y = 4 + 3 * x + np.random.randn(100, 1)

# 시각화 
plt.plot(x,y ,'b.') 
plt.xlabel('x1' , fontsize = 15)
plt.ylabel('y' , rotation=0, fontsize = 15)
plt.axis([0,2,0,15])
plt.show()

# %%
x_new = np.array([[0], [2]])
x_new_b = np.c_[np.ones((2,1)), x_new] # 모든 샘플에 x0 = 1 을 추가
theta_best = np.linalg.inv(x_b.T.dot(x_b)).dot(x_b.T).dot(y)
y_predict = x_new_b.dot(theta_best)
y_predict
# Out:
# array([[7.31013103],
#        [6.37228348]])

# %%
plt.plot(x_new ,y_predict, 'r-', linewidth=2, label="predictor")
plt.plot(x , y , 'b.')
plt.axis([0,2,0,15])
plt.legend(loc="top ", fontsize=14)

plt.show()
# Out:
# array([[0],
#        [2]])
